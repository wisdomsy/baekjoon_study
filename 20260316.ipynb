# %%
# 24263 알고리즘의 수행 시간2

n=int(input())
print(n)
print(1)
# Out:
# 7
# 7
# 1

# %%
# 24264 알고리즘의 수행 시간 3
n=int(input())
print(n**2)
print(2)
# Out:
# 7
# 49
# 2

# %%
# 24265 알고리즘의 수행 시간 4
n=int(input())
print(n*(n-1)//2)
print(2)
# Out:
# 7
# 21
# 2

# %%
# 24265 알고리즘의 수행 시간 4
n=int(input())
print(n**3)
print(3)
# Out:
# 7
# 343
# 3
