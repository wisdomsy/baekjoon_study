# %%
#10807
N=int(input())
li=input()
v=input()
count=0
li=li.split(' ')
for i in range(N):
  if li[i]==v:
    count+=1
print(count)
# Out:
# 11
# 1 4 1 2 4 2 4 2 3 4 4
# 2
# 3

# %%
#10871
N,X=map(int,input().split())
li=input()
li=li.split(' ')
count=0
result=[]
for i in range(N):
  if int(li[i])<X:
    result.append(li[i])
for i in range(len(result)):
  print(result[i],end=' ')
# Out:
# 10 5
# 1 10 4 9 2 3 8 5 7 6
# 1 4 2 3
