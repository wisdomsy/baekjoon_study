# %%
#11718
while True:
  try:
    s=input()
    print(s)
  except EOFError:
    break
# Out:
# Hello
# Hello
# Baekjoon
# Baekjoon

# %%
#25083
print('         ,r\'\"7')
print('r`-_   ,\'  ,/ ')
print(' \\. \". L_r\'')
print('   `~\\/')
print('      |')
print('      |')
# Out:
#          ,r'"7
# r`-_   ,'  ,/
#  \. ". L_r'
#    `~\/
#       |
#       |
