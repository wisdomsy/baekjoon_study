# %%
# 2751 수 정렬하기 2

n=int(input())
result=[]
for i in range(n):
  num=int(input())
  result.append(num)

result.sort()
for i in range(len(result)):
  print(result[i])
# Out:
# 5
# 5
# 4
# 3
# 2
# 1
# 1
# 2
# 3
# 4
# 5
