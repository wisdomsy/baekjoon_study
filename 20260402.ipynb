# %%
#2750 수 정렬하기
n=int(input())
result=[]
for i in range(n):
  number=int(input())
  result.append(number)
result.sort()
for i in range(n):
  print(result[i])
# Out:
# 5
# 5
# 4
# 2
# 3
# 1
# 1
# 2
# 3
# 4
# 5
