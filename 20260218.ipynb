# %%
#2438
n=int(input())
for i in range(n):
  print('*'*(i+1))
# Out:
# 5
# *
# **
# ***
# ****
# *****

# %%
#2439
n=int(input())
for i in range(1,n+1):
  print(' '*(n-i)+'*'*i)
# Out:
# 5
#     *
#    **
#   ***
#  ****
# *****

# %%
#10952
result=[]
while True:
  a,b=map(int,input().split())
  if a==b==0:
    break
  else:
    result.append(a+b)
for i in range(len(result)):
  print(result[i])
# Out:
# 1 1
# 2 3
# 3 4
# 9 8
# 5 2
# 0 0
# 2
# 5
# 7
# 17
# 7

# %%
#10951
while True:
    try:
        a, b = map(int, input().split())
        print(a + b)
    except EOFError:
        break
# Out:
# 1 1
# 2
# 2 3
# 5
# 3 4
# 7
