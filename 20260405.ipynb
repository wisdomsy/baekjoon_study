# %%
#2578 대표값2
num=[]
for i in range(5):
  a=int(input())
  num.append(a)
num.sort()
average=0
for i in range(5):
  average+=num[i]
print(average//5)
print(num[2])
# Out:
# 10
# 40
# 30
# 60
# 30
# 34
# 30
