# %%
#25305 커트라인
n,k=map(int,input().split())
score=input()
score=score.split(' ')
for i in range(len(score)):
  score[i]=int(score[i])

score.sort(reverse=True)
print(score[k-1])
# Out:
# 5 2
# 100 76 85 93 98
# 98
