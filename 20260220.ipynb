# %%
#10818
n=int(input())
num=input()
num=num.split(' ')
for i in range(n):
  num[i]=int(num[i])
print(min(num),max(num))
# Out:
# 5
# 20 10 35 30 7
# 7 35

# %%
#2562
result=[]
for i in range(9):
  num=int(input())
  result.append(num)
max_value=max(result)
for i in range(len(result)):
  if result[i]==max_value:
    print(max_value)
    print(i+1)
# Out:
# 3
# 29
# 38
# 12
# 57
# 74
# 40
# 85
# 61
# 85
# 7
