# %%
#3003
answer=[1,1,2,2,2,8]
state=input()
state=state.split(' ')
for i in range(6):
  print(answer[i]-int(state[i]),end=' ')
# Out:
# 2 1 2 1 2 1
# ['2', '1', '2', '1', '2', '1']
# -1 0 0 1 0 7

# %%
#2444
n=int(input())
for i in range(n):
  print(' '*(n-i-1)+'*'*(2*i+1))
for i in range(n-2,-1,-1):
    print(' '*(n-i-1)+'*'*(2*i+1))
# Out:
# 5
#     *
#    ***
#   *****
#  *******
# *********
#  *******
#   *****
#    ***
#     *

# %%
#10988
check=1
s=input()
length=len(s)
time=length//2
for i in range(time):
  if s[i]!=s[length-1-i]:
    check=0
print(check)
# Out:
# level
# 1
